# %% [markdown]
# ![example](images/director_shot.jpeg)

# %% [markdown]
# # Box Office Trends: Strategic Insights for Microsoft's New Movie Studio
#
#
# **Author:** Prince
# ***

# %% [markdown]
# ## Overview
#
# A one-paragraph overview of the project, including the business problem, data, methods, results and recommendations.

# %% [markdown]
# ## Business Problem
#
# Summary of the business problem you are trying to solve, and the data questions that you plan to answer to solve them.
#
# ***
# Questions to consider:
# * What are the business's pain points related to this project?
# * How did you pick the data analysis question(s) that you did?
# * Why are these questions important from a business perspective?
# ***
#
# Microsoft wants to start its invesment in the original video content creation  so as to come uptodate with the market trends.Being that they want to understand the business before investing they will have to explore what type of films are currently doing good in the box office.This findings will be crucient as they can be used by new head of Microsoft movie studios to make a deecision on what type of films he or she should crreate.

# %% [markdown]
# ## Data Understanding
#
# Describe the data being used for this project.
# ***
# Questions to consider:
# * Where did the data come from, and how do they relate to the data analysis questions?
# * What do the data represent? Who is in the sample and what variables are included?
# * What is the target variable?
# * What are the properties of the variables you intend to use?
# ***
#
# The data came from :
# * Box Office MojoLinks to an external site.
# * IMDBLinks to an external site.
# * Rotten TomatoesLinks to an external site.
# * TheMovieDBLinks to an external site.
# * The Numbers
# which are all renowed movie data sites.
# ***
# The datasets have several veriabels i.e tconst,primary_title,original_title,start_year,runtime_minutes,genres and so on.
# ***
# You should know that we have all this veriabel but our main and terget veriabel is sales price(the determinant)
# ***
#
# #Variable		            #Why It Matters
# * domestic_gross		        Primary measure of revenue (use as SalePrice)
# * foreign_gross		        Optional – for calculating total worldwide revenue
# * runtime_minutes		    Analyze success based on movie length
# * genres		                Grouping and comparison by genre
# * average_rating	            Does higher quality = higher earnings?
# * num_votes		            Use to filter obscure or less relevant films
# * start_year                 For time series trends and filtering

# %%
# Import standard packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
# %matplotlib inline

# %%
# Here you run your code to explore the data
file_path1=r"C:\Users\Administrator\Downloads\imdb.title.basics.csv.gz"
file_path2=r"C:\Users\Administrator\Downloads\imdb.title.ratings.csv.gz"
file_path3=r"C:\Users\Administrator\Downloads\bom.movie_gross.csv.gz"

# %%
imdb_title_basic=pd.read_csv(file_path1)
imdb_title_rating=pd.read_csv(file_path2)
bom_movie_gross=pd.read_csv(file_path3)

# %%
imdb_title_basic.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
imdb_title_basic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146143 non-null  object
#  2   original_title   146122 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
imdb_title_rating.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
imdb_title_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
bom_movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
bom_movie_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %% [markdown]
# ## Data Preparation
#
# Describe and justify the process for preparing the data for analysis.
#
# ***
# Questions to consider:
# * Were there variables you dropped or created?
# * How did you address missing values or outliers?
# * Why are these choices appropriate given the data and the business problem?
# ***

# %% [markdown]
# Joining the data set

# %%
# Here you run your code to clean the data
df=pd.merge(imdb_title_basic,imdb_title_rating,on='tconst',how='inner')
df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes
# 0        2013            175.0    Action,Crime,Drama            7.0        77
# 1        2019            114.0       Biography,Drama            7.2        43
# 2        2018            122.0                 Drama            6.9      4517
# 3        2018              NaN          Comedy,Drama            6.1        13
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5       119

# %%
bom_movie_gross=bom_movie_gross.rename(columns={'title':'primary_title','year':'start_year'})
bom_movie_gross.head()
# Out:
#                                  primary_title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  start_year
# 0     652000000        2010
# 1     691300000        2010
# 2     664300000        2010
# 3     535700000        2010
# 4     513900000        2010

# %%
df=pd.merge(df,bom_movie_gross,on=['primary_title','start_year'],how='inner')
df.head()
# Out:
#       tconst                    primary_title  \
# 0  tt0315642                            Wazir
# 1  tt0337692                      On the Road
# 2  tt0359950  The Secret Life of Walter Mitty
# 3  tt0365907      A Walk Among the Tombstones
# 4  tt0369610                   Jurassic World
#
#                     original_title  start_year  runtime_minutes  \
# 0                            Wazir        2016            103.0
# 1                      On the Road        2012            124.0
# 2  The Secret Life of Walter Mitty        2013            114.0
# 3      A Walk Among the Tombstones        2014            114.0
# 4                   Jurassic World        2015            124.0
#
#                     genres  averagerating  numvotes   studio  domestic_gross  \
# 0       Action,Crime,Drama            7.1     15378  Relbig.       1100000.0
# 1  Adventure,Drama,Romance            6.1     37886      IFC        744000.0
# 2   Adventure,Comedy,Drama            7.3    275300      Fox      58200000.0
# 3       Action,Crime,Drama            6.5    105116     Uni.      26300000.0
# 4  Action,Adventure,Sci-Fi            7.0    539338     Uni.     652300000.0
#
#   foreign_gross
# 0           NaN
# 1       8000000
# 2     129900000
# 3      26900000
# 4       1,019.4

# %%
df.describe()
# Out:
#         start_year  runtime_minutes  averagerating      numvotes  \
# count  1847.000000      1843.000000    1847.000000  1.847000e+03
# mean   2013.972388       110.770483       6.422794  9.166869e+04
# std       2.513624        19.851675       1.004203  1.502088e+05
# min    2010.000000        25.000000       1.600000  6.000000e+00
# 25%    2012.000000        96.000000       5.800000  7.642000e+03
# 50%    2014.000000       107.000000       6.500000  3.546500e+04
# 75%    2016.000000       122.000000       7.100000  1.055535e+05
# max    2018.000000       189.000000       8.800000  1.841066e+06
#
#        domestic_gross
# count    1.837000e+03
# mean     4.278809e+07
# std      7.724321e+07
# min      3.000000e+02
# 25%      5.820000e+05
# 50%      1.070000e+07
# 75%      5.190000e+07
# max      7.001000e+08

# %% [markdown]
# Data cleaning

# %%
df.shape
# Out:
# (1847, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1847 entries, 0 to 1846
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tconst           1847 non-null   object
#  1   primary_title    1847 non-null   object
#  2   original_title   1847 non-null   object
#  3   start_year       1847 non-null   int64
#  4   runtime_minutes  1843 non-null   float64
#  5   genres           1845 non-null   object
#  6   averagerating    1847 non-null   float64
#  7   numvotes         1847 non-null   int64
#  8   studio           1845 non-null   object
#  9   domestic_gross   1837 non-null   float64
#  10  foreign_gross    1269 non-null   object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 158.9+ KB

# %% [markdown]
# Checking extrenous values

# %%
duplicates=df[df.duplicated()]
len(duplicates)
# Out:
# 0

# %%
for cols in df.columns:
    print(cols,'\n',df[cols].value_counts(normalize=True))
# Out:
# tconst
#  tconst
# tt0315642    0.000541
# tt3062096    0.000541
# tt3045616    0.000541
# tt3043630    0.000541
# tt3041550    0.000541
#                ...
# tt1657507    0.000541
# tt1655460    0.000541
# tt1655442    0.000541
# tt1655441    0.000541
# tt9151704    0.000541
# Name: proportion, Length: 1847, dtype: float64
# primary_title
#  primary_title
# Dancer                       0.001083
# Leap Year                    0.001083
# A Better Life                0.001083
# The Call                     0.001083
# The Artist                   0.001083
#                                ...
# Freeheld                     0.000541
# Colombiana                   0.000541
# Wanderlust                   0.000541
# The Age of Adaline           0.000541
# Burn the Stage: The Movie    0.000541
# Name: proportion, Length: 1822, dtype: float64
# original_title
#  original_title
# Dancer                       0.001083
# The Tempest                  0.001083
# Jai Ho                       0.001083
# Gone                         0.001083
# The Negotiation              0.001083
#                                ...
# Freeheld                     0.000541
# Colombiana                   0.000541
# Wanderlust                   0.000541
# The Age of Adaline           0.000541
# Burn the Stage: The Movie    0.000541
# Name: proportion, Length: 1827, dtype: float64
# start_year
#  start_year
# 2016    0.131023
# 2015    0.125609
# 2011    0.115864
# 2012    0.114239
# 2014    0.109908
# 2013    0.104494
# 2010    0.103411
# 2017    0.102870
# 2018    0.092583
# Name: proportion, dtype: float64
# runtime_minutes
#  runtime_minutes
# 100.0    0.026044
# 107.0    0.026044
# 98.0     0.025502
# 106.0    0.025502
# 105.0    0.025502
#            ...
# 66.0     0.000543
# 174.0    0.000543
# 63.0     0.000543
# 77.0     0.000543
# 55.0     0.000543
# Name: proportion, Length: 116, dtype: float64
# genres
#  genres
# Drama                          0.050949
# Comedy,Drama,Romance           0.048780
# Comedy,Drama                   0.038482
# Adventure,Animation,Comedy     0.036856
# Drama,Romance                  0.032520
#                                  ...
# Biography,Crime,Documentary    0.000542
# Action,Comedy,Thriller         0.000542
# Biography,Drama,Fantasy        0.000542
# Animation,Drama                0.000542
# Adventure,Thriller             0.000542
# Name: proportion, Length: 261, dtype: float64
# averagerating
#  averagerating
# 6.3    0.049269
# 6.4    0.047103
# 6.6    0.044938
# 6.2    0.043855
# 6.8    0.042231
#          ...
# 8.7    0.000541
# 2.9    0.000541
# 1.7    0.000541
# 3.0    0.000541
# 2.4    0.000541
# Name: proportion, Length: 64, dtype: float64
# numvotes
#  numvotes
# 12        0.001624
# 43        0.001624
# 21        0.001083
# 1234      0.001083
# 6805      0.001083
#             ...
# 320575    0.000541
# 23135     0.000541
# 177762    0.000541
# 107518    0.000541
# 2067      0.000541
# Name: proportion, Length: 1814, dtype: float64
# studio
#  studio
# Uni.         0.067209
# Fox          0.061247
# WB           0.055285
# BV           0.045528
# Sony         0.043902
#                ...
# Alc          0.000542
# TVC          0.000542
# AF           0.000542
# PH           0.000542
# Trafalgar    0.000542
# Name: proportion, Length: 164, dtype: float64
# domestic_gross
#  domestic_gross
# 1300000.0      0.011432
# 1100000.0      0.009799
# 1800000.0      0.007621
# 1500000.0      0.007077
# 1400000.0      0.005988
#                  ...
# 136000.0       0.000544
# 189400000.0    0.000544
# 993000.0       0.000544
# 104000000.0    0.000544
# 72000.0        0.000544
# Name: proportion, Length: 1195, dtype: float64
# foreign_gross
#  foreign_gross
# 4200000      0.007880
# 2500000      0.006304
# 1200000      0.006304
# 1900000      0.004728
# 1100000      0.004728
#                ...
# 92400000     0.000788
# 300000       0.000788
# 193100000    0.000788
# 111700000    0.000788
# 82100000     0.000788
# Name: proportion, Length: 894, dtype: float64

# %% [markdown]
# Remove the white spaces

# %%
df.columns=df.columns.str.strip()
df=df.apply(lambda x:x.str.lower().str.strip()if x.dtype=='object'else x)
df.head()
# Out:
#       tconst                    primary_title  \
# 0  tt0315642                            wazir
# 1  tt0337692                      on the road
# 2  tt0359950  the secret life of walter mitty
# 3  tt0365907      a walk among the tombstones
# 4  tt0369610                   jurassic world
#
#                     original_title  start_year  runtime_minutes  \
# 0                            wazir        2016            103.0
# 1                      on the road        2012            124.0
# 2  the secret life of walter mitty        2013            114.0
# 3      a walk among the tombstones        2014            114.0
# 4                   jurassic world        2015            124.0
#
#                     genres  averagerating  numvotes   studio  domestic_gross  \
# 0       action,crime,drama            7.1     15378  relbig.       1100000.0
# 1  adventure,drama,romance            6.1     37886      ifc        744000.0
# 2   adventure,comedy,drama            7.3    275300      fox      58200000.0
# 3       action,crime,drama            6.5    105116     uni.      26300000.0
# 4  action,adventure,sci-fi            7.0    539338     uni.     652300000.0
#
#   foreign_gross
# 0           NaN
# 1       8000000
# 2     129900000
# 3      26900000
# 4       1,019.4

# %% [markdown]
# # Dealing with missing values(columns with missing values)
# *  runtime_minutes -1843 values
# *  genres  -1845
# *  studio -1845
# *  domestic_gross -1837
# *  foreign_gross-1269

# %%
df['runtime_minutes'].value_counts()
# Out:
# runtime_minutes
# 100.0    48
# 107.0    48
# 98.0     47
# 106.0    47
# 105.0    47
#          ..
# 66.0      1
# 174.0     1
# 63.0      1
# 77.0      1
# 55.0      1
# Name: count, Length: 116, dtype: int64

# %%
#sns.histplot('runtime_minutes',bins=5)
#plt.show()
fig,ax=plt.subplots(figsize=(10,8))
ax.hist(df['runtime_minutes'],bins=10)
plt.title('distribution of runtime')
plt.show()

# %% [markdown]
# It has a normal distribution so i will fill the missing values using thei mean

# %%
df['runtime_minutes'].mean()
# Out:
# 110.77048290830169

# %%
df['runtime_minutes']=df['runtime_minutes'].fillna(df['runtime_minutes'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1847 entries, 0 to 1846
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tconst           1847 non-null   object
#  1   primary_title    1847 non-null   object
#  2   original_title   1847 non-null   object
#  3   start_year       1847 non-null   int64
#  4   runtime_minutes  1847 non-null   float64
#  5   genres           1845 non-null   object
#  6   averagerating    1847 non-null   float64
#  7   numvotes         1847 non-null   int64
#  8   studio           1845 non-null   object
#  9   domestic_gross   1837 non-null   float64
#  10  foreign_gross    1269 non-null   object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 158.9+ KB

# %%
df['genres'].value_counts().head(10)
# Out:
# genres
# drama                         94
# comedy,drama,romance          90
# comedy,drama                  71
# adventure,animation,comedy    68
# drama,romance                 60
# comedy                        59
# comedy,romance                55
# documentary                   46
# action,adventure,sci-fi       45
# action,adventure,drama        35
# Name: count, dtype: int64

# %% [markdown]
# I will fill the missing values with 'uknown' that will later be treated as category on itself

# %%
df['genres']=df['genres'].fillna('Uknown')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1847 entries, 0 to 1846
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tconst           1847 non-null   object
#  1   primary_title    1847 non-null   object
#  2   original_title   1847 non-null   object
#  3   start_year       1847 non-null   int64
#  4   runtime_minutes  1847 non-null   float64
#  5   genres           1847 non-null   object
#  6   averagerating    1847 non-null   float64
#  7   numvotes         1847 non-null   int64
#  8   studio           1845 non-null   object
#  9   domestic_gross   1837 non-null   float64
#  10  foreign_gross    1269 non-null   object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 158.9+ KB

# %%
df['studio'].value_counts().head(10)
# Out:
# studio
# uni.    124
# fox     113
# wb      102
# bv       84
# sony     81
# par.     78
# lgf      78
# eros     72
# foxs     57
# ifc      53
# Name: count, dtype: int64

# %%
df['studio'].isnull().sum()
# Out:
# 2

# %% [markdown]
# Since it has 'uni' as the mode i will use it to replace the issing values

# %%
df['studio']=df['studio'].fillna('uni.')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1847 entries, 0 to 1846
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tconst           1847 non-null   object
#  1   primary_title    1847 non-null   object
#  2   original_title   1847 non-null   object
#  3   start_year       1847 non-null   int64
#  4   runtime_minutes  1847 non-null   float64
#  5   genres           1847 non-null   object
#  6   averagerating    1847 non-null   float64
#  7   numvotes         1847 non-null   int64
#  8   studio           1847 non-null   object
#  9   domestic_gross   1837 non-null   float64
#  10  foreign_gross    1269 non-null   object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 158.9+ KB

# %%
df['foreign_gross'].isnull().sum()
# Out:
# 578

# %% [markdown]
# Since they are many i will first check the distribution

# %%
df['foreign_gross']=pd.to_numeric(df['foreign_gross'].str.replace(',','',regex=False))

# %%
fig,ax=plt.subplots(figsize=(10,8))
ax.hist(df['foreign_gross'],bins=10)
plt.title('Distribution of foreihgn_gross')
plt.show()

# %% [markdown]
# The distribution is skiewed positively so i will use the median to fill the missing values

# %%
df['foreign_gross']=df['foreign_gross'].fillna(df['foreign_gross'].median())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1847 entries, 0 to 1846
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tconst           1847 non-null   object
#  1   primary_title    1847 non-null   object
#  2   original_title   1847 non-null   object
#  3   start_year       1847 non-null   int64
#  4   runtime_minutes  1847 non-null   float64
#  5   genres           1847 non-null   object
#  6   averagerating    1847 non-null   float64
#  7   numvotes         1847 non-null   int64
#  8   studio           1847 non-null   object
#  9   domestic_gross   1837 non-null   float64
#  10  foreign_gross    1847 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 158.9+ KB

# %% [markdown]
# I want to detect and removeoutliers

# %%
numeric_df=df.select_dtypes(include='number')
fig,(ax)=plt.subplots(figsize=(10,8))
ax.boxplot(numeric_df.values)
ax.set_xticklabels(numeric_df.columns)
ax.set_title('Boxplot to Detect Outliers')
ax.set_xlabel('columns')
plt.show()

# %% [markdown]
# # Removing the outliers
# I wont remove outliers cos they show the real thing on the ground. Outliers on columns like numvote shows that there might have been a block buster moveis and that all there is no need of removing that .

# %% [markdown]
# ## Data Modeling
# Describe and justify the process for analyzing or modeling the data.
#
# ***
# Questions to consider:
# * How did you analyze or model the data?
# * How did you iterate on your initial approach to make it better?
# * Why are these choices appropriate given the data and the business problem?
# ***

# %%
# Here you run your code to model the data
df.head()
# Out:
#       tconst                    primary_title  \
# 0  tt0315642                            wazir
# 1  tt0337692                      on the road
# 2  tt0359950  the secret life of walter mitty
# 3  tt0365907      a walk among the tombstones
# 4  tt0369610                   jurassic world
#
#                     original_title  start_year  runtime_minutes  \
# 0                            wazir        2016            103.0
# 1                      on the road        2012            124.0
# 2  the secret life of walter mitty        2013            114.0
# 3      a walk among the tombstones        2014            114.0
# 4                   jurassic world        2015            124.0
#
#                     genres  averagerating  numvotes   studio  domestic_gross  \
# 0       action,crime,drama            7.1     15378  relbig.       1100000.0
# 1  adventure,drama,romance            6.1     37886      ifc        744000.0
# 2   adventure,comedy,drama            7.3    275300      fox      58200000.0
# 3       action,crime,drama            6.5    105116     uni.      26300000.0
# 4  action,adventure,sci-fi            7.0    539338     uni.     652300000.0
#
#    foreign_gross
# 0     31300000.0
# 1      8000000.0
# 2    129900000.0
# 3     26900000.0
# 4         1019.4

# %% [markdown]
# creating a new column total_gross

# %%
df['total_gross']=df['domestic_gross']+df['foreign_gross']

# %%
df.head()
# Out:
#       tconst                    primary_title  \
# 0  tt0315642                            wazir
# 1  tt0337692                      on the road
# 2  tt0359950  the secret life of walter mitty
# 3  tt0365907      a walk among the tombstones
# 4  tt0369610                   jurassic world
#
#                     original_title  start_year  runtime_minutes  \
# 0                            wazir        2016            103.0
# 1                      on the road        2012            124.0
# 2  the secret life of walter mitty        2013            114.0
# 3      a walk among the tombstones        2014            114.0
# 4                   jurassic world        2015            124.0
#
#                     genres  averagerating  numvotes   studio  domestic_gross  \
# 0       action,crime,drama            7.1     15378  relbig.       1100000.0
# 1  adventure,drama,romance            6.1     37886      ifc        744000.0
# 2   adventure,comedy,drama            7.3    275300      fox      58200000.0
# 3       action,crime,drama            6.5    105116     uni.      26300000.0
# 4  action,adventure,sci-fi            7.0    539338     uni.     652300000.0
#
#    foreign_gross  total_gross
# 0     31300000.0   32400000.0
# 1      8000000.0    8744000.0
# 2    129900000.0  188100000.0
# 3     26900000.0   53200000.0
# 4         1019.4  652301019.4

# %% [markdown]
# Ill then dropp the other two columns

# %%
df=df.drop(['domestic_gross','foreign_gross'],axis=1)
df.head()
# Out:
#       tconst                    primary_title  \
# 0  tt0315642                            wazir
# 1  tt0337692                      on the road
# 2  tt0359950  the secret life of walter mitty
# 3  tt0365907      a walk among the tombstones
# 4  tt0369610                   jurassic world
#
#                     original_title  start_year  runtime_minutes  \
# 0                            wazir        2016            103.0
# 1                      on the road        2012            124.0
# 2  the secret life of walter mitty        2013            114.0
# 3      a walk among the tombstones        2014            114.0
# 4                   jurassic world        2015            124.0
#
#                     genres  averagerating  numvotes   studio  total_gross
# 0       action,crime,drama            7.1     15378  relbig.   32400000.0
# 1  adventure,drama,romance            6.1     37886      ifc    8744000.0
# 2   adventure,comedy,drama            7.3    275300      fox  188100000.0
# 3       action,crime,drama            6.5    105116     uni.   53200000.0
# 4  action,adventure,sci-fi            7.0    539338     uni.  652301019.4

# %%
df['start_year'].value_counts()
# Out:
# start_year
# 2016    242
# 2015    232
# 2011    214
# 2012    211
# 2014    203
# 2013    193
# 2010    191
# 2017    190
# 2018    171
# Name: count, dtype: int64

# %% [markdown]
# Checking the corelation between total_gross and other veriabel-how dose they affect it
#
# ***
# Correlation betweeen total_gross and start_year

# %%
cols=['total_gross','start_year','runtime_minutes','averagerating','numvotes']
plt.figure(figsize=(10,8))
sns.heatmap(df[cols].corr(),annot=True,cmap='YlGnBu')
plt.title('A heatmap to detemine how deferent veriabels affect total_gross')
plt.savefig('correlation_heatmap.png',bbox_inches='tight')
plt.show()

# %% [markdown]
# Most of the veriabels have a positive corelation to total gross with numvotes having the highest corelation of 0.67 to mean that num vote highly affect the prices in the market.This also indicate that an increase in the number of people voting a film will automaticaly lead to increase  of film sales in the market.
# ***
# We  also have start year with a very weak positive corelation of about 0.052(lets say this is a very weak or no correlation).This suggest that the year in which a film was realeased into the market dose not affect the rate at which sales are made in market

# %% [markdown]
# Seeing that numvotes has a very high positive corelation with total gross lets look into it and see how the real the relationshp is using a scater plot
# # scatter plot

# %%
sns.set_context("talk")  
sns.set_style("whitegrid")
df['genres'] = df['genres'].astype(str).str.split(',')

df_exploded = df.explode('genres')
df_exploded = df_exploded.reset_index(drop=True)

top_genres = df_exploded['genres'].value_counts().head(10).index.to_list()
df_top = df_exploded[df_exploded['genres'].isin(top_genres)]

fig, axes = plt.subplots(1, 2, figsize=(30, 20), sharey=True)
sns.scatterplot(
    data=df_exploded,
    x='numvotes', y='total_gross',
    hue='genres', alpha=0.5, palette='tab20',
    ax=axes[0], legend=True
)
axes[0].set_title('All Genres',fontsize=18)
axes[0].set_xlabel('numvotes',fontsize=14)
axes[0].set_ylabel('total_gross',fontsize=14)

sns.scatterplot(
    data=df_top,
    x='numvotes', y='total_gross',
    hue='genres', alpha=0.6, palette='bright',
    ax=axes[1]
)
axes[1].set_title('Top 10 Genres Only',fontsize=18)
axes[1].set_xlabel('numvotes',fontsize=14)
axes[1].set_ylabel('total_gross',fontsize=14)

fig.suptitle('How numvotes affect total gross across genres', fontsize=16)
plt.tight_layout()
plt.savefig('votes_vs_gross_by_genre.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Observation
# There is a noticeable correlation between a film's popularity (number of votes) and its total box office gross. Most high-grossing films also received a large number of votes, especially in the action, adventure, and thriller genres. Conversely, genres like romance, and news tend to remain in the lower popularity and revenue ranges.
#
# ***
#
# It is also important to note that the dense dots at the illustrate that most of those films with lower numvote are prone to lower totalgross e.g romance and news

# %% [markdown]
# # Trends over time and by content

# %%
df['genres'].value_counts()
# Out:
# genres
# drama                         94
# comedy,drama,romance          90
# comedy,drama                  71
# adventure,animation,comedy    68
# drama,romance                 60
#                               ..
# documentary,musical            1
# action,documentary,history     1
# documentary,drama              1
# action,horror,mystery          1
# action,mystery,sci-fi          1
# Name: count, Length: 262, dtype: int64

# %%
df['total_gross']=df['total_gross']/1000000

# %%
df['genres']=df['genres'].astype(str).str.split(',')
df=df.explode('genres')
top_genres= df['genres'].value_counts().head(10).index.to_list()
df=df[df['genres'].isin(top_genres)]
grouped_df=df.groupby(['start_year','genres'])['total_gross'].mean().reset_index()
plt.figure(figsize=(10,8))
sns.barplot(grouped_df,x='start_year',y='total_gross',hue='genres',palette='bright')
plt.title('Average total gross by year and genres')
plt.ylabel('Average_total gross')
plt.legend(title='genres',bbox_to_anchor=(1.05,1),loc='upper left')
plt.tight_layout()
plt.savefig('genre_vs_year.png',bbox_inches='tight')
plt.show()

# %% [markdown]
# # Observations
# The graph above shows the average box office gross have evolved overtime from 2010-2018 for the top 10 most popular genres.
# ***
# Action based films and adventures have consistently given a lead for the highest average gross making them safe genres to fund across region and very ideal for big budgets

# %% [markdown]
# ## Evaluation
# Evaluate how well your work solves the stated business problem.
#
# ***
# Questions to consider:
# * How do you interpret the results?
# * How well does your model fit your data? How much better is this than your baseline model?
# * How confident are you that your results would generalize beyond the data you have?
# * How confident are you that this model would benefit the business if put into use?
# ***
# How do you interpret the results?
# * The correlation heatmap showed that numvotes and averagerating are positively associated with total_gross, suggesting that higher audience engagement and positive reception may lead to better revenue.
#
# * The grouped bar plot revealed that certain genres — especially adventure and action — consistently produce higher average gross revenues across multiple years.
#
# ***
# How well does your model fit your data?
# * Although a predictive model was not applied at this stage, the exploratory techniques used (grouped aggregation and correlation) effectively highlighted patterns and relationships within the dataset. These findings serve as a strong foundation for further predictive modeling if needed.
#
# ***
# How confident are you that your results would generalize beyond the data?
# * The analysis was based on real-world data from multiple sources, including IMDB and Box Office Mojo. While the data is representative of general movie trends between 2010 and 2018, it's possible that changes in the film industry or streaming trends could affect generalizability. However, the identified relationships — such as the strong influence of genre and audience engagement — are likely to remain relevant.
# ***
# How confident are you that this model would benefit the business?
# * Very confident. The analysis provides data-backed insights that a business like Microsoft could use to:
#
# * Choose genres more likely to succeed at the box office.
#
# * Prioritize films with higher viewer engagement and ratings.
#
# * Avoid projects in lower-performing categories based on historical performance.
#
# While this work does not yet include predictive forecasting, it significantly narrows down the factors worth investing in — which directly supports strategic decision-making.

# %% [markdown]
# ## Conclusions
# Provide your conclusions about the work you've done, including any limitations or next steps.
#
# ***
# Questions to consider:
# * What would you recommend the business do as a result of this work?
# * What are some reasons why your analysis might not fully solve the business problem?
# * What else could you do in the future to improve this project?
# ***
#
# * Genres like adventure and action consistently perform well across years.
#
# * Audience engagement metrics such as numvotes and averagerating have a strong positive correlation with total_gross.
#
# Based on these findings, we recommend that the business:
#
# * Prioritize movie production in high-grossing genres like adventure and action.
#
# * Consider audience reception indicators (ratings and vote counts) when evaluating potential film projects.
#
# * Use historical data trends to inform budgeting and marketing strategies.
#
# ***
# Despite its insights, this analysis has some limitations:
#
# * No predictive model was built — we didn’t quantify how well one could forecast revenue.
#
# * Data gaps like missing total_gross or runtime values required imputation or led to reduced sample size.
#
# * Time-limited data: Most of the data covered movies released between 2010–2018, and may not reflect newer streaming-driven trends.
#
# ***
# To further strengthen this analysis, future work could include:
#
# * Building a linear regression or machine learning model to predict box office performance.
#
# * Including marketing spend, cast popularity, and release date as features if data becomes available.
#
# * Exploring streaming performance data to reflect evolving consumption patterns in the film industry.
